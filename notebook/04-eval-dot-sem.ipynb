# %%
# %cd /kaggle/working
# !git clone https://github.com/nguyenmaiductrong/absa-sota-survey.git
# %cd absa-sota-survey
# Out:
# /kaggle/working
# Cloning into 'absa-sota-survey'...
# remote: Enumerating objects: 444, done.
# remote: Counting objects: 100% (444/444), done.
# remote: Compressing objects: 100% (287/287), done.
# remote: Total 444 (delta 203), reused 366 (delta 147), pack-reused 0 (from 0)
# Receiving objects: 100% (444/444), 6.08 MiB | 20.30 MiB/s, done.
# Resolving deltas: 100% (203/203), done.
# /kaggle/working/absa-sota-survey

# %% [markdown]
# ## Cài đặt các thư viện cần thiết

# %%
# %cd /kaggle/working/absa-sota-survey
# !pip install -q -r requirements.txt
# Out:
# /kaggle/working/absa-sota-survey
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 88.4 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 99.6 MB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 101.0 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 88.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.1/459.1 kB 35.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Đánh giá tập restaurant

# %%
import os
os.chdir("/kaggle/working/absa-sota-survey")

# !python evaluate.py \
  --predictor predictors.dot:DOTPredictor \
  --predictor-kwargs '{"checkpoint_phase1": "/kaggle/input/notebooks/nxuanwuy/dot-train-restaurant/checkpoints/dot_rest/first", "checkpoint_phase2": "/kaggle/input/notebooks/nxuanwuy/dot-train-restaurant/checkpoints/dot_rest/final"}' \
  --test-set /kaggle/working/absa-sota-survey/data/processed/dot/rest/test.jsonl \
  --output-dir /kaggle/working/absa-sota-survey/results

# %% [markdown]
# ## Đánh giá tập laptop

# %%
import os
os.chdir("/kaggle/working/absa-sota-survey")

# !python evaluate.py \
  --predictor predictors.dot:DOTPredictor \
  --predictor-kwargs '{"checkpoint_phase1": "/kaggle/input/notebooks/b22dckh099lngminhqu/dot-train-laptop/checkpoints/dot_laptop/first", "checkpoint_phase2": "/kaggle/input/notebooks/b22dckh099lngminhqu/dot-train-laptop/checkpoints/dot_laptop/final"}' \
  --test-set /kaggle/working/absa-sota-survey/data/processed/dot/laptop/test.jsonl \
  --output-dir /kaggle/working/absa-sota-survey/results
