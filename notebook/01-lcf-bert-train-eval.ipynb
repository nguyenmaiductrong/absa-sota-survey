# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4

# %%
# %cd /kaggle/working
# !git clone https://github.com/nguyenmaiductrong/absa-sota-survey.git
# %cd absa-sota-survey
# Out:
# /kaggle/working
# Cloning into 'absa-sota-survey'...
# remote: Enumerating objects: 205, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 205 (delta 84), reused 177 (delta 65), pack-reused 0 (from 0)
# Receiving objects: 100% (205/205), 3.53 MiB | 19.00 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /kaggle/working/absa-sota-survey

# %% [markdown]
# ## Load thư viện cần thiết

# %%
# %cd /kaggle/working/absa-sota-survey
# !pip install -q -r requirements.txt
# Out:
# /kaggle/working/absa-sota-survey
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 88.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 99.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 102.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 86.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 80.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.1/459.1 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.1/183.1 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 96.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.66.2 which is incompatible.
# kaggle-environments 1.27.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# s3fs 2026.2.0 requires fsspec==2026.2.0, but you have fsspec 2024.3.1 which is incompatible.
# tpot 1.1.0 requires dill>=0.3.9, but you have dill 0.3.8 which is incompatible.
# tpot 1.1.0 requires scikit-learn>=1.6, but you have scikit-learn 1.4.1.post1 which is incompatible.
# ydata-profiling 4.18.1 requires requests<3,>=2.32.0, but you have requests 2.31.0 which is incompatible.
# ydata-profiling 4.18.1 requires tqdm<5,>=4.66.3, but you have tqdm 4.66.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# category-encoders 2.9.0 requires scikit-learn>=1.6.0, but you have scikit-learn 1.4.1.post1 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.31.0 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cuml-cu12 26.2.0 requires scikit-learn>=1.5, but you have scikit-learn 1.4.1.post1 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# umap-learn 0.5.11 requires scikit-learn>=1.6, but you have scikit-learn 1.4.1.post1 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# dataproc-spark-connect 1.0.2 requires tqdm>=4.67, but you have tqdm 4.66.2 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# hdbscan 0.8.41 requires scikit-learn>=1.6, but you have scikit-learn 1.4.1.post1 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires tqdm>=4.67, but you have tqdm 4.66.2 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# imbalanced-learn 0.14.1 requires scikit-learn<2,>=1.4.2, but you have scikit-learn 1.4.1.post1 which is incompatible.
# google-adk 1.25.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.31.0 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# libpysal 4.14.1 requires requests>=2.32.0, but you have requests 2.31.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.3.1 which is incompatible.
# gradio 5.50.0 requires typer<1.0,>=0.12, but you have typer 0.9.4 which is incompatible.

# %% [markdown]
# ## Training

# %%
# !python models/lcf_bert/train.py --config configs/lcf_bert_en_restaurant.yaml
# Out:
# 15:40:02 INFO Device: cuda
# 15:40:02 INFO Dataset: SemEval-2014-Restaurant
# 15:40:02 INFO Sentiments: 3 | Aspects: 5
# 15:40:02 INFO use_gold_aspect_input: True
# 15:40:02 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 15:40:02 INFO HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 15:40:02 WARNING Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 2.79MB/s]
# 15:40:03 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 258kB/s]
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 15:40:03 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# vocab.txt: 232kB [00:00, 9.34MB/s]
# 15:40:03 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# 15:40:03 INFO HTTP Request: GET https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json: 466kB [00:00, 7.28MB/s]
# 15:40:03 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 15:40:03 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json "HTTP/1.1 404 Not Found"
# 15:40:04 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 15:40:07 INFO Train: 3518 | Val: 973 | skipped train/val: 0/0
# 15:40:07 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 15:40:07 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 15:40:07 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 15:40:08 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 15:40:08 INFO HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/xet-read-token/86b5e0934494bd15c9632b12f734a8a67f723594 "HTTP/1.1 200 OK"
# model.safetensors:  76%|████████████████▋     | 335M/440M [00:02<00:00, 135MB/s]
# The following layers were not sharded: encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.attention.output.LayerNorm.weight, embeddings.LayerNorm.bias, encoder.layer.*.attention.self.key.weight, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.attention.self.value.bias, embeddings.token_type_embeddings.weight, pooler.dense.weight, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.output.dense.bias, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.bias, encoder.layer.*.attention.self.query.weight, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.key.bias, embeddings.word_embeddings.weight, encoder.layer.*.intermediate.dense.weight, encoder.layer.*.attention.self.value.weight, pooler.dense.bias, embeddings.LayerNorm.weight, encoder.layer.*.output.dense.weight, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.output.dense.weight
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1573.11it/s, Materializing param=
# 15:40:23 INFO epoch 1/10 step 50/220 loss=0.8236
# 15:40:33 INFO epoch 1/10 step 100/220 loss=0.7287
# 15:40:44 INFO epoch 1/10 step 150/220 loss=0.6601
# 15:40:55 INFO epoch 1/10 step 200/220 loss=0.6214
# 15:40:59 INFO epoch 1/10 step 220/220 loss=0.6034
# 15:41:14 INFO Epoch 1/10 | sent_acc=0.8787 sent_f1=0.7748
# 15:41:14 INFO Saved best checkpoint: checkpoints/semeval14_rest/lcf_bert_best.pt (sentiment_macro_f1=0.7748)
# 15:41:26 INFO epoch 2/10 step 50/220 loss=0.3189
# 15:41:37 INFO epoch 2/10 step 100/220 loss=0.3362
# 15:41:48 INFO epoch 2/10 step 150/220 loss=0.3319
# 15:42:00 INFO epoch 2/10 step 200/220 loss=0.3397
# 15:42:04 INFO epoch 2/10 step 220/220 loss=0.3365
# 15:42:19 INFO Epoch 2/10 | sent_acc=0.8941 sent_f1=0.8232
# 15:42:20 INFO Saved best checkpoint: checkpoints/semeval14_rest/lcf_bert_best.pt (sentiment_macro_f1=0.8232)
# 15:42:31 INFO epoch 3/10 step 50/220 loss=0.2063
# 15:42:43 INFO epoch 3/10 step 100/220 loss=0.2008
# 15:42:54 INFO epoch 3/10 step 150/220 loss=0.2061
# 15:43:05 INFO epoch 3/10 step 200/220 loss=0.2155
# 15:43:09 INFO epoch 3/10 step 220/220 loss=0.2151
# 15:43:25 INFO Epoch 3/10 | sent_acc=0.8880 sent_f1=0.8164
# 15:43:36 INFO epoch 4/10 step 50/220 loss=0.1054
# 15:43:47 INFO epoch 4/10 step 100/220 loss=0.1270
# 15:43:58 INFO epoch 4/10 step 150/220 loss=0.1400
# 15:44:10 INFO epoch 4/10 step 200/220 loss=0.1520
# 15:44:14 INFO epoch 4/10 step 220/220 loss=0.1505
# 15:44:29 INFO Epoch 4/10 | sent_acc=0.8859 sent_f1=0.8140
# 15:44:40 INFO epoch 5/10 step 50/220 loss=0.0560
# 15:44:52 INFO epoch 5/10 step 100/220 loss=0.0947
# 15:45:03 INFO epoch 5/10 step 150/220 loss=0.0958
# 15:45:14 INFO epoch 5/10 step 200/220 loss=0.1005
# 15:45:19 INFO epoch 5/10 step 220/220 loss=0.1043
# 15:45:34 INFO Epoch 5/10 | sent_acc=0.8869 sent_f1=0.8152
# 15:45:34 INFO Early stopping: no improvement in sentiment_macro_f1 for 3 epoch(s). Best sentiment_macro_f1=0.8232
# 15:45:34 INFO Training done. Best sentiment_macro_f1: 0.8232

# %%
# !python models/lcf_bert/train.py --config configs/lcf_bert_en_laptop.yaml
# Out:
# 15:45:43 INFO Device: cuda
# 15:45:43 INFO Dataset: SemEval-2014-Laptop
# 15:45:43 INFO Sentiments: 3 | Aspects: 1181
# 15:45:43 INFO use_gold_aspect_input: True
# 15:45:44 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 15:45:44 WARNING Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 15:45:44 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# 15:45:44 INFO HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 15:45:44 INFO HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 15:45:44 INFO HTTP Request: GET https://huggingface.co/api/models/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 15:45:44 INFO HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-uncased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 15:45:46 INFO Train: 2313 | Val: 638 | skipped train/val: 0/0
# 15:45:47 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# 15:45:47 INFO HTTP Request: HEAD https://huggingface.co/bert-base-uncased/resolve/main/config.json "HTTP/1.1 200 OK"
# The following layers were not sharded: embeddings.LayerNorm.bias, encoder.layer.*.attention.self.key.weight, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.output.LayerNorm.weight, embeddings.token_type_embeddings.weight, encoder.layer.*.output.dense.bias, encoder.layer.*.intermediate.dense.weight, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.output.LayerNorm.bias, encoder.layer.*.attention.self.value.bias, encoder.layer.*.output.dense.weight, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.query.weight, embeddings.LayerNorm.weight, pooler.dense.bias, encoder.layer.*.attention.output.LayerNorm.weight, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.attention.self.value.weight, pooler.dense.weight, encoder.layer.*.output.LayerNorm.bias, embeddings.word_embeddings.weight, encoder.layer.*.attention.self.key.bias, encoder.layer.*.attention.output.dense.bias
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1675.00it/s, Materializing param=
# 15:45:59 INFO epoch 1/10 step 50/145 loss=0.9544
# 15:46:10 INFO epoch 1/10 step 100/145 loss=0.8247
# 15:46:21 INFO epoch 1/10 step 145/145 loss=0.7448
# 15:46:31 INFO Epoch 1/10 | sent_acc=0.7414 sent_f1=0.6473
# 15:46:32 INFO Saved best checkpoint: checkpoints/semeval14_lap/lcf_bert_best.pt (sentiment_macro_f1=0.6473)
# 15:46:43 INFO epoch 2/10 step 50/145 loss=0.4953
# 15:46:54 INFO epoch 2/10 step 100/145 loss=0.4729
# 15:47:04 INFO epoch 2/10 step 145/145 loss=0.4757
# 15:47:14 INFO Epoch 2/10 | sent_acc=0.7586 sent_f1=0.6845
# 15:47:15 INFO Saved best checkpoint: checkpoints/semeval14_lap/lcf_bert_best.pt (sentiment_macro_f1=0.6845)
# 15:47:26 INFO epoch 3/10 step 50/145 loss=0.3214
# 15:47:38 INFO epoch 3/10 step 100/145 loss=0.3201
# 15:47:48 INFO epoch 3/10 step 145/145 loss=0.3356
# 15:47:58 INFO Epoch 3/10 | sent_acc=0.7571 sent_f1=0.7032
# 15:47:59 INFO Saved best checkpoint: checkpoints/semeval14_lap/lcf_bert_best.pt (sentiment_macro_f1=0.7032)
# 15:48:10 INFO epoch 4/10 step 50/145 loss=0.2115
# 15:48:21 INFO epoch 4/10 step 100/145 loss=0.2337
# 15:48:31 INFO epoch 4/10 step 145/145 loss=0.2323
# 15:48:41 INFO Epoch 4/10 | sent_acc=0.7962 sent_f1=0.7516
# 15:48:42 INFO Saved best checkpoint: checkpoints/semeval14_lap/lcf_bert_best.pt (sentiment_macro_f1=0.7516)
# 15:48:53 INFO epoch 5/10 step 50/145 loss=0.1649
# 15:49:05 INFO epoch 5/10 step 100/145 loss=0.1563
# 15:49:15 INFO epoch 5/10 step 145/145 loss=0.1667
# 15:49:25 INFO Epoch 5/10 | sent_acc=0.7665 sent_f1=0.7187
# 15:49:36 INFO epoch 6/10 step 50/145 loss=0.0825
# 15:49:47 INFO epoch 6/10 step 100/145 loss=0.0865
# 15:49:57 INFO epoch 6/10 step 145/145 loss=0.0912
# 15:50:07 INFO Epoch 6/10 | sent_acc=0.7555 sent_f1=0.6959
# 15:50:18 INFO epoch 7/10 step 50/145 loss=0.0499
# 15:50:30 INFO epoch 7/10 step 100/145 loss=0.0658
# 15:50:40 INFO epoch 7/10 step 145/145 loss=0.0720
# 15:50:50 INFO Epoch 7/10 | sent_acc=0.7571 sent_f1=0.6973
# 15:50:50 INFO Early stopping: no improvement in sentiment_macro_f1 for 3 epoch(s). Best sentiment_macro_f1=0.7516
# 15:50:50 INFO Training done. Best sentiment_macro_f1: 0.7516

# %%
# !python models/lcf_bert/train.py --config configs/lcf_bert_vi.yaml
# Out:
# 15:50:58 INFO Device: cuda
# 15:50:58 INFO Dataset: UIT-VSFC
# 15:50:58 INFO Sentiments: 3 | Aspects: 4
# 15:50:58 INFO use_gold_aspect_input: True
# 15:50:58 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 15:50:58 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 15:50:58 INFO HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 557/557 [00:00<00:00, 3.47MB/s]
# 15:50:58 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer_config.json "HTTP/1.1 404 Not Found"
# 15:50:58 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer_config.json "HTTP/1.1 404 Not Found"
# 15:50:59 INFO HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 15:50:59 INFO HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/vocab.txt "HTTP/1.1 307 Temporary Redirect"
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/vocab.txt "HTTP/1.1 200 OK"
# 15:50:59 INFO HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/vocab.txt "HTTP/1.1 200 OK"
# vocab.txt: 895kB [00:00, 21.2MB/s]
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/bpe.codes "HTTP/1.1 307 Temporary Redirect"
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/bpe.codes "HTTP/1.1 200 OK"
# 15:50:59 INFO HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/bpe.codes "HTTP/1.1 200 OK"
# bpe.codes: 1.14MB [00:00, 94.6MB/s]
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 15:50:59 WARNING Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/special_tokens_map.json "HTTP/1.1 404 Not Found"
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/tokenizer.json "HTTP/1.1 200 OK"
# 15:50:59 INFO HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json: 3.13MB [00:00, 134MB/s]
# 15:50:59 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# 15:51:10 INFO Train: 11426 | Val: 1583 | skipped train/val: 0/0
# 15:51:10 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 15:51:10 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 15:51:10 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 15:51:11 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 15:51:11 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 15:51:11 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 15:51:11 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 15:51:11 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 15:51:11 INFO HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/xet-read-token/c1e37c5c86f918761049cef6fa216b4779d0d01d "HTTP/1.1 200 OK"
# pytorch_model.bin: 100%|██████████████████████| 543M/543M [00:03<00:00, 172MB/s]
# 15:51:14 INFO HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 15:51:14 INFO HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base "HTTP/1.1 200 OK"
# The following layers were not sharded: encoder.layer.*.attention.output.LayerNorm.bias, pooler.dense.weight, embeddings.LayerNorm.weight, encoder.layer.*.attention.self.key.weight, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.output.dense.bias, embeddings.word_embeddings.weight, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.weight, embeddings.token_type_embeddings.weight, embeddings.LayerNorm.bias, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.output.dense.weight, encoder.layer.*.attention.self.query.weight, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.value.bias, encoder.layer.*.attention.self.query.bias, encoder.layer.*.output.LayerNorm.bias, pooler.dense.bias, encoder.layer.*.attention.self.value.weight, encoder.layer.*.intermediate.dense.weight, encoder.layer.*.attention.self.key.bias
# 15:51:15 INFO HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base
# 16:24:16 INFO Epoch 8/10 | sent_acc=0.9356 sent_f1=0.8385
# 16:24:16 INFO Early stopping: no improvement in sentiment_macro_f1 for 3 epoch(s). Best sentiment_macro_f1=0.8491
# 16:24:16 INFO Training done. Best sentiment_macro_f1: 0.8491

# %% [markdown]
# ## Evaluate

# %%
# !python evaluate.py \
  --predictor predictors.lcf_bert:LCFBertPredictor \
  --predictor-kwargs '{"checkpoint":"checkpoints/semeval14_rest/lcf_bert_best.pt"}' \
  --test-set data/processed/lcf_bert/semeval14_rest_test.jsonl \
  --given-aspect --output-dir results
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# The following layers were not sharded: pooler.dense.weight, encoder.layer.*.intermediate.dense.weight, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.self.key.weight, encoder.layer.*.output.dense.weight, pooler.dense.bias, encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.weight, embeddings.word_embeddings.weight, embeddings.token_type_embeddings.weight, encoder.layer.*.output.dense.bias, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.attention.self.key.bias, encoder.layer.*.attention.self.value.bias, embeddings.LayerNorm.bias, encoder.layer.*.attention.self.value.weight, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.attention.self.query.weight, embeddings.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.bias
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1641.29it/s, Materializing param=
# [evaluate] 100/973 samples (10%) - last latency 20.2 ms
# [evaluate] 200/973 samples (21%) - last latency 20.4 ms
# [evaluate] 300/973 samples (31%) - last latency 20.3 ms
# [evaluate] 400/973 samples (41%) - last latency 20.4 ms
# [evaluate] 500/973 samples (51%) - last latency 20.3 ms
# [evaluate] 600/973 samples (62%) - last latency 21.3 ms
# [evaluate] 700/973 samples (72%) - last latency 20.1 ms
# [evaluate] 800/973 samples (82%) - last latency 20.3 ms
# [evaluate] 900/973 samples (92%) - last latency 22.7 ms
# [evaluate] wrote results/predictions/lcf_bert_semeval14_rest.jsonl and results/metrics/lcf_bert_semeval14_rest.json
# {
#   "method": "LCF-BERT",
#   "paradigm": "Discriminative",
#   "backbone": "bert-base-uncased",
#   "dataset": "SemEval-2014-Restaurant",
#   "n_samples": 973,
#   "sentiment_accuracy": 0.8941,
#   "sentiment_macro_f1": 0.8232,
#   "parse_error_rate": 0.0,
#   "evaluation_protocol": "given_aspect_absc",
#   "given_aspect": true,
#   "avg_latency_ms": 20.805,
#   "efficiency": {
#     "params_million": null,
#     "gpu_mem_peak_gb": 0.454,
#     "training_hours": null,
#     "hardware": "1x T4 16GB",
#     "precision": "fp16",
#     "batch_size_inference": 1
#   }
# }

# %%
# !python evaluate.py \
  --predictor predictors.lcf_bert:LCFBertPredictor \
  --predictor-kwargs '{"checkpoint":"checkpoints/semeval14_lap/lcf_bert_best.pt"}' \
  --test-set data/processed/lcf_bert/semeval14_lap_test.jsonl \
  --given-aspect --output-dir results
# Out:
# The following layers were not sharded: encoder.layer.*.output.dense.weight, encoder.layer.*.attention.self.key.bias, encoder.layer.*.attention.self.value.bias, embeddings.word_embeddings.weight, pooler.dense.bias, encoder.layer.*.attention.self.query.weight, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.output.LayerNorm.bias, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.self.key.weight, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.intermediate.dense.weight, encoder.layer.*.attention.self.value.weight, embeddings.token_type_embeddings.weight, encoder.layer.*.output.dense.bias, embeddings.position_embeddings.weight, pooler.dense.weight, encoder.layer.*.attention.output.LayerNorm.weight, embeddings.LayerNorm.weight, embeddings.LayerNorm.bias
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1833.12it/s, Materializing param=
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [evaluate] 100/638 samples (16%) - last latency 22.7 ms
# [evaluate] 200/638 samples (31%) - last latency 20.8 ms
# [evaluate] 300/638 samples (47%) - last latency 21.0 ms
# [evaluate] 400/638 samples (63%) - last latency 21.7 ms
# [evaluate] 500/638 samples (78%) - last latency 21.9 ms
# [evaluate] 600/638 samples (94%) - last latency 22.4 ms
# [evaluate] wrote results/predictions/lcf_bert_semeval14_lap.jsonl and results/metrics/lcf_bert_semeval14_lap.json
# {
#   "method": "LCF-BERT",
#   "paradigm": "Discriminative",
#   "backbone": "bert-base-uncased",
#   "dataset": "SemEval-2014-Laptop",
#   "n_samples": 638,
#   "sentiment_accuracy": 0.7962,
#   "sentiment_macro_f1": 0.7516,
#   "parse_error_rate": 0.0,
#   "evaluation_protocol": "given_aspect_absc",
#   "given_aspect": true,
#   "avg_latency_ms": 21.348,
#   "efficiency": {
#     "params_million": null,
#     "gpu_mem_peak_gb": 0.454,
#     "training_hours": null,
#     "hardware": "1x T4 16GB",
#     "precision": "fp16",
#     "batch_size_inference": 1
#   }
# }

# %%
# !python evaluate.py \
  --predictor predictors.lcf_bert:LCFBertPredictor \
  --predictor-kwargs '{"checkpoint":"checkpoints/vsfc/lcf_bert_best.pt"}' \
  --test-set data/processed/lcf_bert/vsfc_test.jsonl \
  --given-aspect --output-dir results
# Out:
# The following layers were not sharded: encoder.layer.*.intermediate.dense.weight, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.output.dense.weight, encoder.layer.*.output.LayerNorm.bias, embeddings.LayerNorm.bias, encoder.layer.*.attention.output.LayerNorm.weight, encoder.layer.*.attention.self.key.weight, encoder.layer.*.attention.self.value.bias, encoder.layer.*.output.dense.bias, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.output.LayerNorm.bias, pooler.dense.weight, embeddings.word_embeddings.weight, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.attention.self.query.weight, encoder.layer.*.intermediate.dense.bias, pooler.dense.bias, embeddings.LayerNorm.weight, encoder.layer.*.attention.self.key.bias, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.value.weight, embeddings.token_type_embeddings.weight
# Loading weights: 100%|█| 199/199 [00:00<00:00, 3823.13it/s, Materializing param=
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [evaluate] 100/3166 samples (3%) - last latency 19.9 ms
# [evaluate] 200/3166 samples (6%) - last latency 20.7 ms
# [evaluate] 300/3166 samples (9%) - last latency 19.5 ms
# [evaluate] 400/3166 samples (13%) - last latency 19.3 ms
# [evaluate] 500/3166 samples (16%) - last latency 20.1 ms
# [evaluate] 600/3166 samples (19%) - last latency 20.2 ms
# [evaluate] 700/3166 samples (22%) - last latency 21.6 ms
# [evaluate] 800/3166 samples (25%) - last latency 20.9 ms
# [evaluate] 900/3166 samples (28%) - last latency 20.3 ms
# [evaluate] 1000/3166 samples (32%) - last latency 20.2 ms
# [evaluate] 1100/3166 samples (35%) - last latency 21.9 ms
# [evaluate] 1200/3166 samples (38%) - last latency 20.0 ms
# [evaluate] 1300/3166 samples (41%) - last latency 21.1 ms
# [evaluate] 1400/3166 samples (44%) - last latency 22.1 ms
# [evaluate] 1500/3166 samples (47%) - last latency 20.0 ms
# [evaluate] 1600/3166 samples (51%) - last latency 20.7 ms
# [evaluate] 1700/3166 samples (54%) - last latency 19.8 ms
# [evaluate] 1800/3166 samples (57%) - last latency 19.9 ms
# [evaluate] 1900/3166 samples (60%) - last latency 19.8 ms
# [evaluate] 2000/3166 samples (63%) - last latency 20.1 ms
# [evaluate] 2100/3166 samples (66%) - last latency 20.4 ms
# [evaluate] 2200/3166 samples (69%) - last latency 20.5 ms
# [evaluate] 2300/3166 samples (73%) - last latency 21.6 ms
# [evaluate] 2400/3166 samples (76%) - last latency 20.3 ms
# [evaluate] 2500/3166 samples (79%) - last latency 19.9 ms
# [evaluate] 2600/3166 samples (82%) - last latency 20.0 ms
# [evaluate] 2700/3166 samples (85%) - last latency 20.0 ms
# [evaluate] 2800/3166 samples (88%) - last latency 20.1 ms
# [evaluate] 2900/3166 samples (92%) - last latency 20.3 ms
# [evaluate] 3000/3166 samples (95%) - last latency 20.0 ms
# [evaluate] 3100/3166 samples (98%) - last latency 20.2 ms
# [evaluate] wrote results/predictions/lcf_bert_vsfc.jsonl and results/metrics/lcf_bert_vsfc.json
# {
#   "method": "LCF-BERT",
#   "paradigm": "Discriminative",
#   "backbone": "vinai/phobert-base",
#   "dataset": "UIT-VSFC",
#   "n_samples": 3166,
#   "sentiment_accuracy": 0.9274,
#   "sentiment_macro_f1": 0.8121,
#   "parse_error_rate": 0.0,
#   "evaluation_protocol": "given_aspect_absc",
#   "given_aspect": true,
#   "avg_latency_ms": 20.304,
#   "efficiency": {
#     "params_million": null,
#     "gpu_mem_peak_gb": 0.549,
#     "training_hours": null,
#     "hardware": "1x T4 16GB",
#     "precision": "fp16",
#     "batch_size_inference": 1
#   }
# }
