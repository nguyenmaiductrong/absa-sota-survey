# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4

# %%
# %cd /kaggle/working
# !git clone https://github.com/nguyenmaiductrong/absa-sota-survey.git
# %cd absa-sota-survey
# Out:
# /kaggle/working
# Cloning into 'absa-sota-survey'...
# remote: Enumerating objects: 396, done.
# remote: Counting objects: 100% (396/396), done.
# remote: Compressing objects: 100% (253/253), done.
# remote: Total 396 (delta 179), reused 338 (delta 133), pack-reused 0 (from 0)
# Receiving objects: 100% (396/396), 5.31 MiB | 19.33 MiB/s, done.
# Resolving deltas: 100% (179/179), done.
# /kaggle/working/absa-sota-survey

# %%
# %cd /kaggle/working/absa-sota-survey
# !pip install -q -r requirements.txt
# Out:
# /kaggle/working/absa-sota-survey
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 90.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 93.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.1/459.1 kB 25.8 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p /kaggle/working/checkpoints/dot_laptop

# %%
import os
os.chdir("/kaggle/working/absa-sota-survey/models/dot")
print(os.getcwd())
# Out:
# /kaggle/working/absa-sota-survey/models/dot

# %%
# !python train.py \
    --data_path ../../data/processed/dot \
    --task asqp \
    --dataset laptop \
    --model_name t5-base \
    --output_dir /kaggle/working/checkpoints/dot_laptop \
    --do_train \
    --num_train_epochs 20 \
    --train_batch_size 16 \
    --eval_batch_size 16 \
    --learning_rate 1e-4 \
    --seed 25 \
    --save_top_k 1 \
    --check_val_every_n_epoch 1
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...
# spiece.model: 100%|██████████████████████████| 792k/792k [00:00<00:00, 3.76MB/s]
# tokenizer.json: 1.39MB [00:00, 7.97MB/s]
# Total examples = 2741
# 2741
# config.json: 1.21kB [00:00, 4.95MB/s]
# model.safetensors: 100%|██████████████████████| 892M/892M [00:03<00:00, 288MB/s]
# Loading weights: 100%|█| 257/257 [00:00<00:00, 1831.63it/s, Materializing param=
# generation_config.json: 100%|███████████████████| 147/147 [00:00<00:00, 767kB/s]
# ...
